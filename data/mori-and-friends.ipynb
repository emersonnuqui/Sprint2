# %%
import numpy as np
import pandas as pd

# %%
charts_df = pd.read_csv('data/spotify_daily_charts.csv')
# transform date column into a datetime column
charts_df['date'] = pd.to_datetime(charts_df['date'])
tracks_df = pd.read_csv('data/spotify_daily_charts_tracks.csv')

streams_df = charts_df.merge(tracks_df, on='track_id', how='left')
streams_df = streams_df.drop(columns='track_name_y')
streams_df = streams_df.rename(columns={'track_name_x': 'track_name'})
streams_df.head()
# Out:
#         date  position                track_id            track_name  \
# 0 2017-01-01         1  0kN8xEmgMW9mh7UmDYHlJP  Versace on the Floor
# 1 2017-01-01         1  0kN8xEmgMW9mh7UmDYHlJP  Versace on the Floor
# 2 2017-01-01         1  0kN8xEmgMW9mh7UmDYHlJP  Versace on the Floor
# 3 2017-01-01         2  5uCax9HTNlzGybIStD3vDh  Say You Won't Let Go
# 4 2017-01-01         2  5uCax9HTNlzGybIStD3vDh  Say You Won't Let Go
#
#          artist  streams               artist_id   artist_name  \
# 0    Bruno Mars   185236  0du5cEVh5yTK9QJze8zA0C    Bruno Mars
# 1    Bruno Mars   185236  0du5cEVh5yTK9QJze8zA0C    Bruno Mars
# 2    Bruno Mars   185236  0du5cEVh5yTK9QJze8zA0C    Bruno Mars
# 3  James Arthur   180552  4IWBUUAFIplrNtaOHcJPRM  James Arthur
# 4  James Arthur   180552  4IWBUUAFIplrNtaOHcJPRM  James Arthur
#
#                  album_id  duration  ... energy   key  loudness  mode  \
# 0  4PgleR09JVnm3zY1fW3XBA    261240  ...  0.574   2.0    -6.209   1.0
# 1  4PgleR09JVnm3zY1fW3XBA    261240  ...  0.574   2.0    -6.209   1.0
# 2  4PgleR09JVnm3zY1fW3XBA    261240  ...  0.574   2.0    -6.209   1.0
# 3  7oiJYvEJHsmYtrgviAVIBD    211466  ...  0.557  10.0    -7.398   1.0
# 4  7oiJYvEJHsmYtrgviAVIBD    211466  ...  0.557  10.0    -7.398   1.0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo
# 0       0.0454         0.196               0.0    0.0830    0.301  174.152
# 1       0.0454         0.196               0.0    0.0830    0.301  174.152
# 2       0.0454         0.196               0.0    0.0830    0.301  174.152
# 3       0.0590         0.695               0.0    0.0902    0.494   85.043
# 4       0.0590         0.695               0.0    0.0902    0.494   85.043
#
# [5 rows x 23 columns]

# %%
streams_df.columns
# Out:
# Index(['date', 'position', 'track_id', 'track_name', 'artist', 'streams',
#        'artist_id', 'artist_name', 'album_id', 'duration', 'release_date',
#        'popularity', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo'],
#       dtype='object')

# %%
df_mori = streams_df[
    (streams_df['artist']=='Angeline Quinto') | (streams_df['artist']=='Jona') |
    (streams_df['artist']=='Morissette') | (streams_df['artist']=='Regine Velasquez') |
    (streams_df['artist']=='Sarah Geronimo') 
    ]
df_mori
# Out:
#              date  position                track_id  \
# 198    2017-01-01        91  0Dljpp52vCmtXi0E94qjfo
# 199    2017-01-01        91  0Dljpp52vCmtXi0E94qjfo
# 370    2017-01-01       177  0JzwzRDkwZr8s1WRfNgUqA
# 371    2017-01-01       177  0JzwzRDkwZr8s1WRfNgUqA
# 604    2017-01-02        85  0Dljpp52vCmtXi0E94qjfo
# ...           ...       ...                     ...
# 363651 2020-12-06       200  4T7CM071eEoHudiDShZlCJ
# 364070 2020-12-08       198  4T7CM071eEoHudiDShZlCJ
# 364281 2020-12-09       197  4T7CM071eEoHudiDShZlCJ
# 368430 2020-12-29       199  4T7CM071eEoHudiDShZlCJ
# 368840 2020-12-31       190  4T7CM071eEoHudiDShZlCJ
#
#                                       track_name           artist  streams  \
# 198     Maybe This Time - From "Maybe This Time"   Sarah Geronimo    19821
# 199     Maybe This Time - From "Maybe This Time"   Sarah Geronimo    19821
# 370                               Till I Met You  Angeline Quinto    11649
# 371                               Till I Met You  Angeline Quinto    11649
# 604     Maybe This Time - From "Maybe This Time"   Sarah Geronimo    23890
# ...                                          ...              ...      ...
# 363651                                      Tala   Sarah Geronimo    25326
# 364070                                      Tala   Sarah Geronimo    27916
# 364281                                      Tala   Sarah Geronimo    29114
# 368430                                      Tala   Sarah Geronimo    26852
# 368840                                      Tala   Sarah Geronimo    34365
#
#                      artist_id      artist_name                album_id  \
# 198     6aiCKnIN68hohzU3ZzNq48   Sarah Geronimo  0BGReR0ClYIme8zAabt53h
# 199     6aiCKnIN68hohzU3ZzNq48   Sarah Geronimo  0BGReR0ClYIme8zAabt53h
# 370     7DW4ijH3n36QN0RlC0n649  Angeline Quinto  0NfAzxHZ4diQArSqZMTJHc
# 371     7DW4ijH3n36QN0RlC0n649  Angeline Quinto  0NfAzxHZ4diQArSqZMTJHc
# 604     6aiCKnIN68hohzU3ZzNq48   Sarah Geronimo  0BGReR0ClYIme8zAabt53h
# ...                        ...              ...                     ...
# 363651  6aiCKnIN68hohzU3ZzNq48   Sarah Geronimo  42F8uTX1DR3OiaKVtrz3Gr
# 364070  6aiCKnIN68hohzU3ZzNq48   Sarah Geronimo  42F8uTX1DR3OiaKVtrz3Gr
# 364281  6aiCKnIN68hohzU3ZzNq48   Sarah Geronimo  42F8uTX1DR3OiaKVtrz3Gr
# 368430  6aiCKnIN68hohzU3ZzNq48   Sarah Geronimo  42F8uTX1DR3OiaKVtrz3Gr
# 368840  6aiCKnIN68hohzU3ZzNq48   Sarah Geronimo  42F8uTX1DR3OiaKVtrz3Gr
#
#         duration  ... energy  key  loudness  mode  speechiness  acousticness  \
# 198       255608  ...  0.273  6.0    -7.697   1.0       0.0362         0.705
# 199       255608  ...  0.273  6.0    -7.697   1.0       0.0362         0.705
# 370       240065  ...  0.476  2.0    -8.042   1.0       0.0338         0.689
# 371       240065  ...  0.476  2.0    -8.042   1.0       0.0338         0.689
# 604       255608  ...  0.273  6.0    -7.697   1.0       0.0362         0.705
# ...          ...  ...    ...  ...       ...   ...          ...           ...
# 363651    245053  ...  0.795  8.0    -1.602   1.0       0.0497         0.623
# 364070    245053  ...  0.795  8.0    -1.602   1.0       0.0497         0.623
# 364281    245053  ...  0.795  8.0    -1.602   1.0       0.0497         0.623
# 368430    245053  ...  0.795  8.0    -1.602   1.0       0.0497         0.623
# 368840    245053  ...  0.795  8.0    -1.602   1.0       0.0497         0.623
#
#         instrumentalness  liveness  valence    tempo
# 198             0.000000    0.1170    0.176  134.124
# 199             0.000000    0.1170    0.176  134.124
# 370             0.000002    0.3610    0.172  139.833
# 371             0.000002    0.3610    0.172  139.833
# 604             0.000000    0.1170    0.176  134.124
# ...                  ...       ...      ...      ...
# 363651          0.000193    0.0971    0.499   97.999
# 364070          0.000193    0.0971    0.499   97.999
# 364281          0.000193    0.0971    0.499   97.999
# 368430          0.000193    0.0971    0.499   97.999
# 368840          0.000193    0.0971    0.499   97.999
#
# [5022 rows x 23 columns]

# %%
mori = df_mori.loc[:, ['artist','track_name','track_id','album_id']]
mori
# Out:
#                  artist                                track_name  \
# 198      Sarah Geronimo  Maybe This Time - From "Maybe This Time"
# 199      Sarah Geronimo  Maybe This Time - From "Maybe This Time"
# 370     Angeline Quinto                            Till I Met You
# 371     Angeline Quinto                            Till I Met You
# 604      Sarah Geronimo  Maybe This Time - From "Maybe This Time"
# ...                 ...                                       ...
# 363651   Sarah Geronimo                                      Tala
# 364070   Sarah Geronimo                                      Tala
# 364281   Sarah Geronimo                                      Tala
# 368430   Sarah Geronimo                                      Tala
# 368840   Sarah Geronimo                                      Tala
#
#                       track_id                album_id
# 198     0Dljpp52vCmtXi0E94qjfo  0BGReR0ClYIme8zAabt53h
# 199     0Dljpp52vCmtXi0E94qjfo  0BGReR0ClYIme8zAabt53h
# 370     0JzwzRDkwZr8s1WRfNgUqA  0NfAzxHZ4diQArSqZMTJHc
# 371     0JzwzRDkwZr8s1WRfNgUqA  0NfAzxHZ4diQArSqZMTJHc
# 604     0Dljpp52vCmtXi0E94qjfo  0BGReR0ClYIme8zAabt53h
# ...                        ...                     ...
# 363651  4T7CM071eEoHudiDShZlCJ  42F8uTX1DR3OiaKVtrz3Gr
# 364070  4T7CM071eEoHudiDShZlCJ  42F8uTX1DR3OiaKVtrz3Gr
# 364281  4T7CM071eEoHudiDShZlCJ  42F8uTX1DR3OiaKVtrz3Gr
# 368430  4T7CM071eEoHudiDShZlCJ  42F8uTX1DR3OiaKVtrz3Gr
# 368840  4T7CM071eEoHudiDShZlCJ  42F8uTX1DR3OiaKVtrz3Gr
#
# [5022 rows x 4 columns]
